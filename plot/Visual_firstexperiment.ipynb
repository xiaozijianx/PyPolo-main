# %%
from pathlib import Path
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
import pandas as pd
import os

import pypolo2

# %% [markdown]
# type = "2023072207080401" 代表：日期20230722+车辆数07+数据开始时间08+污染源数04+变化速度0.1

# %%
# 从data.npz文件中加载数组
deadline = 30
randomsource = False
grid_x = 20
grid_y = 20
Strategy = "AirPollutionexperimentforforestfire_Nonmyopic_Adaptive_Sensing_Operation"
sche_step = 8
adaptive_step = 2
Env = "Dynamic"
alpha = 0.5
adaptive = "Adaptive"
With_water = "Without_Replenish"
spray = "Control"
effect_threshold = 0.0
team_size = 7
type = "2023072207080401" 
filename = './outputs/x{}_y{}_{}_{}_{}_{}_teamsize{}_threshold{}_schestep{}_adaptivestep{}_result_{}_{}.npz'.format(grid_x, grid_y,\
    Strategy,Env,With_water,spray,team_size,effect_threshold,sche_step,adaptive_step,type,randomsource)
data = np.load(filename)
env_list_loaded = data['env_list']
# print(env_list_loaded1[0].shape)
mean_pollution_list = []
max_pollution_list = []
for env in env_list_loaded:
    mean = np.mean(env)
    max = np.max(env)
    mean_pollution_list.append(mean)
    max_pollution_list.append(max)
mean_pollution1_1 = np.array(mean_pollution_list)
max_pollution1_1 = np.array(max_pollution_list)

team_size = 7
type = "2023072207080402"
filename = './outputs/x{}_y{}_{}_{}_{}_{}_teamsize{}_threshold{}_schestep{}_adaptivestep{}_result_{}_{}.npz'.format(grid_x, grid_y,\
    Strategy,Env,With_water,spray,team_size,effect_threshold,sche_step,adaptive_step,type,randomsource)
data = np.load(filename)
env_list_loaded = data['env_list']
# print(env_list_loaded1[0].shape)
mean_pollution_list = []
max_pollution_list = []
for env in env_list_loaded:
    mean = np.mean(env)
    max = np.max(env)
    mean_pollution_list.append(mean)
    max_pollution_list.append(max)
mean_pollution2_1 = np.array(mean_pollution_list)
max_pollution2_1 = np.array(max_pollution_list)

team_size = 7
type = "2023072207080404"
filename = './outputs/x{}_y{}_{}_{}_{}_{}_teamsize{}_threshold{}_schestep{}_adaptivestep{}_result_{}_{}.npz'.format(grid_x, grid_y,\
    Strategy,Env,With_water,spray,team_size,effect_threshold,sche_step,adaptive_step,type,randomsource)
data = np.load(filename)
env_list_loaded = data['env_list']
# print(env_list_loaded1[0].shape)

mean_pollution_list = []
max_pollution_list = []
for env in env_list_loaded:
    mean = np.mean(env)
    max = np.max(env)
    mean_pollution_list.append(mean)
    max_pollution_list.append(max)
mean_pollution3_1 = np.array(mean_pollution_list)
max_pollution3_1 = np.array(max_pollution_list)

Strategy = "AirPollutionexperimentforforestfire_Nonmyopic_Adaptive_Operation"
team_size = 7
type = "2023072207080401"
filename = './outputs/x{}_y{}_{}_{}_{}_{}_teamsize{}_threshold{}_schestep{}_adaptivestep{}_result_{}_{}.npz'.format(grid_x, grid_y,\
    Strategy,Env,With_water,spray,team_size,effect_threshold,sche_step,adaptive_step,type,randomsource)
data = np.load(filename)
env_list_loaded = data['env_list']
# print(env_list_loaded1[0].shape)
mean_pollution_list = []
max_pollution_list = []
for env in env_list_loaded:
    mean = np.mean(env)
    max = np.max(env)
    mean_pollution_list.append(mean)
    max_pollution_list.append(max)
mean_pollution1_2 = np.array(mean_pollution_list)
max_pollution1_2 = np.array(max_pollution_list)

team_size = 7
type = "2023072207080402"
filename = './outputs/x{}_y{}_{}_{}_{}_{}_teamsize{}_threshold{}_schestep{}_adaptivestep{}_result_{}_{}.npz'.format(grid_x, grid_y,\
    Strategy,Env,With_water,spray,team_size,effect_threshold,sche_step,adaptive_step,type,randomsource)
data = np.load(filename)
env_list_loaded = data['env_list']
# print(env_list_loaded1[0].shape)
mean_pollution_list = []
max_pollution_list = []
for env in env_list_loaded:
    mean = np.mean(env)
    max = np.max(env)
    mean_pollution_list.append(mean)
    max_pollution_list.append(max)
mean_pollution2_2 = np.array(mean_pollution_list)
max_pollution2_2 = np.array(max_pollution_list)

team_size = 7
type = "2023072207080404"
filename = './outputs/x{}_y{}_{}_{}_{}_{}_teamsize{}_threshold{}_schestep{}_adaptivestep{}_result_{}_{}.npz'.format(grid_x, grid_y,\
    Strategy,Env,With_water,spray,team_size,effect_threshold,sche_step,adaptive_step,type,randomsource)
data = np.load(filename)
env_list_loaded = data['env_list']
# print(env_list_loaded1[0].shape)

mean_pollution_list = []
max_pollution_list = []
for env in env_list_loaded:
    mean = np.mean(env)
    max = np.max(env)
    mean_pollution_list.append(mean)
    max_pollution_list.append(max)
mean_pollution3_2 = np.array(mean_pollution_list)
max_pollution3_2 = np.array(max_pollution_list)

Strategy = "AirPollutionexperimentforforestfire_Without_Operation"
team_size = 7
type = "2023072207080401"
filename = './outputs/x{}_y{}_{}_{}_{}_{}_teamsize{}_threshold{}_schestep{}_adaptivestep{}_result_{}_{}.npz'.format(grid_x, grid_y,\
    Strategy,Env,With_water,spray,team_size,effect_threshold,sche_step,adaptive_step,type,randomsource)
data = np.load(filename)
env_list_loaded = data['env_list']
# print(env_list_loaded1[0].shape)
mean_pollution_list = []
max_pollution_list = []
for env in env_list_loaded:
    mean = np.mean(env)
    max = np.max(env)
    mean_pollution_list.append(mean)
    max_pollution_list.append(max)
mean_pollution1_3 = np.array(mean_pollution_list)
max_pollution1_3 = np.array(max_pollution_list)

team_size = 7
type = "2023072207080402"
filename = './outputs/x{}_y{}_{}_{}_{}_{}_teamsize{}_threshold{}_schestep{}_adaptivestep{}_result_{}_{}.npz'.format(grid_x, grid_y,\
    Strategy,Env,With_water,spray,team_size,effect_threshold,sche_step,adaptive_step,type,randomsource)
data = np.load(filename)
env_list_loaded = data['env_list']
# print(env_list_loaded1[0].shape)
mean_pollution_list = []
max_pollution_list = []
for env in env_list_loaded:
    mean = np.mean(env)
    max = np.max(env)
    mean_pollution_list.append(mean)
    max_pollution_list.append(max)
mean_pollution2_3 = np.array(mean_pollution_list)
max_pollution2_3 = np.array(max_pollution_list)

team_size = 7
type = "2023072207080404"
filename = './outputs/x{}_y{}_{}_{}_{}_{}_teamsize{}_threshold{}_schestep{}_adaptivestep{}_result_{}_{}.npz'.format(grid_x, grid_y,\
    Strategy,Env,With_water,spray,team_size,effect_threshold,sche_step,adaptive_step,type,randomsource)
data = np.load(filename)
env_list_loaded = data['env_list']
# print(env_list_loaded1[0].shape)

mean_pollution_list = []
max_pollution_list = []
for env in env_list_loaded:
    mean = np.mean(env)
    max = np.max(env)
    mean_pollution_list.append(mean)
    max_pollution_list.append(max)
mean_pollution3_3 = np.array(mean_pollution_list)
max_pollution3_3 = np.array(max_pollution_list)

mean_pollution1_1_alltime = np.mean(mean_pollution1_1[deadline-1]) 
mean_pollution1_2_alltime = np.mean(mean_pollution1_2[deadline-1]) 
mean_pollution1_3_alltime = np.mean(mean_pollution1_3[deadline-1]) 
mean_pollution2_1_alltime = np.mean(mean_pollution2_1[deadline-1]) 
mean_pollution2_2_alltime = np.mean(mean_pollution2_2[deadline-1]) 
mean_pollution2_3_alltime = np.mean(mean_pollution2_3[deadline-1]) 
mean_pollution3_1_alltime = np.mean(mean_pollution3_1[deadline-1]) 
mean_pollution3_2_alltime = np.mean(mean_pollution3_2[deadline-1]) 
mean_pollution3_3_alltime = np.mean(mean_pollution3_3[deadline-1]) 

# 三组数据
data = np.array([[mean_pollution1_1_alltime, mean_pollution1_2_alltime, mean_pollution1_3_alltime], 
                 [mean_pollution2_1_alltime, mean_pollution2_2_alltime, mean_pollution2_3_alltime], 
                 [mean_pollution3_1_alltime, mean_pollution3_2_alltime, mean_pollution3_3_alltime]])

# 每组数据的标签
labels = ['Low release rate', 'Medium release rate', 'High release rate']

# 每组数据中每个柱状图的标签
data_labels = ['Sensing-Operation', 'Operation', 'No control']

# x轴的刻度
x_ticks = np.arange(len(labels))

# 绘制柱状图
plt.bar(x_ticks - 0.2, data[:, 0], width=0.2, align='center', label=data_labels[0])
plt.bar(x_ticks, data[:, 1], width=0.2, align='center', label=data_labels[1])
plt.bar(x_ticks + 0.2, data[:, 2], width=0.2, align='center', label=data_labels[2])

# 设置x轴的标签和刻度
plt.xticks(x_ticks, labels)

# 设置y轴的范围和刻度
plt.ylim(30, 120)

# 添加图例
plt.legend()

# 添加标题
plt.title('pm2.5 concentration(μg/m³)')

# 显示图形
plt.show()

# %%
# 三组数据
data = np.array([[mean_pollution1_1_alltime, mean_pollution1_2_alltime], 
                 [mean_pollution2_1_alltime, mean_pollution2_2_alltime], 
                 [mean_pollution3_1_alltime, mean_pollution3_2_alltime]])

# 每组数据的标签
labels = ['Low release rate', 'Medium release rate', 'High release rate']

# 每组数据中每个柱状图的标签
data_labels = ['Sensing-Operation', 'Operation']

# x轴的刻度
x_ticks = np.arange(len(labels))

# 绘制柱状图
plt.bar(x_ticks - 0.2, data[:, 0], width=0.2, align='center', label=data_labels[0])
plt.bar(x_ticks, data[:, 1], width=0.2, align='center', label=data_labels[1])

# 设置x轴的标签和刻度
plt.xticks(x_ticks, labels)

# 设置y轴的范围和刻度
plt.ylim(30, 80)

# 添加图例
plt.legend()

# plt.ylabel('pm2.5 concentration(μg/m³)',fontsize=10,color='black')

# 添加标题
plt.title('pm2.5 concentration(μg/m³)')

# 显示图形
plt.show()

# %%
# 创建一个新的Matplotlib图形
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
# 绘制平均污染物浓度
ax.plot(mean_pollution1_1, label='Sensing_Operation-Low_release_rate')
ax.plot(mean_pollution2_1, label='Sensing_Operation-Medium_release_rate')
ax.plot(mean_pollution3_1, label='Sensing_Operation-High_release_rate')
ax.plot(mean_pollution1_2, label='Operation-Low_release_rate')
ax.plot(mean_pollution2_2, label='Operation-Medium_release_rate')
ax.plot(mean_pollution3_2, label='Operation-High_release_rate')
ax.legend()
ax.set_xlabel('time')
ax.set_ylabel('Mean pm2.5 concentration(μg/m³)')
ax.set_title('Mean pollution Comparison')

# # 显示图形
plt.show()
