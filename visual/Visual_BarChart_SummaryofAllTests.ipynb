# %%
import sys
sys.path.append('../')
# from experiments import utilities
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly
import plotly_express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
from plot.utils import bar_update_fig, line_update_fig
import pypolo2

width = 1000
height = 800
markersize = 10
linewidth = 4
markersymbol={'FH':4, 'HEUR':17, 'DDRL':2}
linetype = {'Low':'dot','Medium':'dashdot','High':'longdash'}
# 创建一个包含线型的示例数组
line_dash = ['solid', 'dot', 'dash', 'dashdot', 'longdash']
colors_dict = ['#C74223', '#3D9182', '#245C8F']

# %% [markdown]
# # overall performance 1

# %%
models = ['WithoutSprinkle','MCS', 'MCPP', 'SoScheduler',  'Ours']
Average_Concentration = [94.2, 47.2, 40.8, 42.0,  33.1]

width = 1000
height = 666
colors_dict = ['#3D9182','#C74223','#245C8F', '#FF8C00']

labels = np.array(['WithoutSprinkle','MCS', 'MCPP', 'SoScheduler',  'Ours'])
xtitle = 'Sprinkle Strategy'
ytitle = 'Average Suppression of PM2.5(μg/m³)'
fig = go.Figure()
fig.add_trace(go.Bar(
    width= 0.5, 
    x=labels, 
    y=Average_Concentration, 
    name='SmartSpr', 
    marker=dict(line_color=colors_dict[0],color=colors_dict[0], pattern_shape='\\'),
    text=Average_Concentration,  # 添加数据标注
    textposition='outside'  # 自动调整标注位置
    ))

fig.update_traces(
    marker=dict(pattern_fillmode="replace", line_width=3, pattern_size=15),
)

fig = bar_update_fig(fig, xtitle, ytitle, width=width, height=height)
fig.update_layout(
    yaxis=dict(range=[0, 110]),  # 设置y轴范围
    legend=dict(font=dict(size=30), x=0.5, y=1.22, orientation='h')
    )
fig.show()
filename = './outputs/png/Overall_SchedulingPerformance1.png'
print(filename)
fig.write_image(filename, scale=1)

# %% [markdown]
# # overall performance 2

# %%
models = ['WithoutSprinkle','MCS', 'TRACT', 'SoScheduler',  'Ours']
Average_Concentration = [78.4, 36.9, 39.3, 43.8,  32.3]

width = 1000
height = 666
colors_dict = ['#3D9182','#C74223','#245C8F', '#FF8C00']

labels = np.array(['WithoutSprinkle','MCS', 'TRACT', 'SoScheduler',  'Ours'])
xtitle = 'Sprinkle Strategy'
ytitle = 'Average Suppression of PM2.5(μg/m³)'
fig = go.Figure()
fig.add_trace(go.Bar(
    width= 0.5, 
    x=labels, 
    y=Average_Concentration, 
    name='SmartSpr', 
    marker=dict(line_color=colors_dict[0],color=colors_dict[0], pattern_shape='\\'),
    text=Average_Concentration,  # 添加数据标注
    textposition='outside'  # 自动调整标注位置
    ))

fig.update_traces(
    marker=dict(pattern_fillmode="replace", line_width=3, pattern_size=15),
)

fig = bar_update_fig(fig, xtitle, ytitle, width=width, height=height)
fig.update_layout(
    yaxis=dict(range=[0, 100]),  # 设置y轴范围
    legend=dict(font=dict(size=30), x=0.5, y=1.22, orientation='h')
    )
fig.show()
filename = './outputs/png/Overall_SchedulingPerformance2.png'
print(filename)
fig.write_image(filename, scale=1)

# %% [markdown]
# # tract VS smartspr

# %%
teamsize = ['2', '3', '4', '5']
nondecoupled = [112, 364, 1008, 1160]
smarspr = [101, 134, 286, 411]

width = 1000
height = 666
colors_dict = ['#3D9182','#C74223','#245C8F', '#FF8C00']

labels = np.array(teamsize)
xtitle = 'Sprinkler Number'
ytitle = 'Runtime(s)'
fig = go.Figure()
fig.add_trace(go.Bar(
    width= 0.4, 
    x=labels, 
    y=nondecoupled, 
    name='Tract', 
    marker=dict(line_color=colors_dict[0],color=colors_dict[0], pattern_shape='\\'),
    text=nondecoupled,  # 添加数据标注
    textposition='outside'  # 自动调整标注位置
    ))

fig.add_trace(go.Bar(
    width= 0.4, 
    x=labels, 
    y=smarspr, 
    name='SmartSpr', 
    marker=dict(line_color=colors_dict[1],color=colors_dict[1], pattern_shape='-'),
    text=smarspr,  # 添加数据标注
    textposition='outside'  # 自动调整标注位置
    ))

fig.update_traces(
    marker=dict(pattern_fillmode="replace", line_width=3, pattern_size=15),
)

fig = bar_update_fig(fig, xtitle, ytitle, width=width, height=height)
fig.update_layout(
    yaxis=dict(range=[0, 1400]),  # 设置y轴范围
    legend=dict(font=dict(size=30), x=0.5, y=1.12, orientation='h')
    )
fig.show()
filename = './outputs/png/performance_varnumsource.png'
print(filename)
fig.write_image(filename, scale=1)

# %% [markdown]
# # average pm2.5 concentration at last two hours

# %%
#区域平均污染物浓度
Setting = pypolo2.utilities.Config()
strategy_name = ["EffectOrientedSelectiveSpray",
                #  "NonmyonicLatticeSpray",
                 "EffectOrientedMCTSSpray",
                #  "EffectOrientedGreedySpray",
                 "MaximumCoverageSpray",
                 "NoSpray"]
comparing_variables = [["teamsize_1","teamsize_2","teamsize_3"],
                       ["numsource_2","numsource_4","numsource_6","numsource_8"],
                       ["change_interval4","change_interval8","change_interval12"]]
# seeds = [0,3,7,11,15,18,32,42,50]
seeds = [7,11,18,20,25,36,42,50,60,72,80,85]
team_sizes = [1,2,3]
sourcenums = [2,4,6,8]
change_intervals = [4,8,12]
total_step = 48
sche_step = 0
adaptive_step = 0
strategy_pm25concentration = []
for strategy in strategy_name:
    if strategy == "EffectOrientedGreedySpray":
        sche_step = 18
        adaptive_step = 18
    elif strategy == "NonmyonicLatticeSpray":
        sche_step = 18
        adaptive_step = 4
    elif strategy == "EffectOrientedMCTSSpray":
        sche_step = 8
        adaptive_step = 8
    else:
        sche_step = 18
        adaptive_step = 3
    variable_pm25concentration = []
    for i in range(3):
        comparing_variable = comparing_variables[0][i]
        team_size = team_sizes[i]
        sourcenum = 3
        seed_pm25concentration = []
        for seed in seeds:
            pklname = f'SEED_{seed}_X{Setting.grid_x}_Y{Setting.grid_y}_VS{team_size}_TS{Setting.max_num_samples}_SS{sche_step}_AS{adaptive_step}_SN{sourcenum}_RS{Setting.replenish_speed}_WV{Setting.water_volume}'
            pkldir = './outputs/' + strategy + '/' + comparing_variable + '/' + pklname + ".pkl"
            data = pypolo2.experiments.utilities.readpkl(pkldir)
            time_pm25concentration = []
            for j in range(total_step):
                if j > 24:
                    pm25concentration = np.mean(data['truth_env'][j])
                    time_pm25concentration.append(pm25concentration)
            seed_pm25concentration.append(np.mean(time_pm25concentration))
        variable_pm25concentration.append(np.mean(seed_pm25concentration))
    strategy_pm25concentration.append(variable_pm25concentration)
strategy_pm25concentration = np.array(strategy_pm25concentration)
strategy_pm25concentration[-1,:] = np.mean(strategy_pm25concentration[-1,:])

width = 1050
height = 650
colors_dict = ['#3D9182','#C74223','#245C8F', '#FF8C00']

labels = np.array(['1 Sprinkle Truck', '2 Sprinkle Truck', '3 Sprinkle Truck'])
xtitle = 'Sprinkle Truck Number'
ytitle = 'PM2.5 Concentration(μg/m³)'
fig = go.Figure()
fig.add_trace(go.Bar(width= 0.2, x=labels, y=strategy_pm25concentration[0,:], name='SmartSpr', marker=dict(line_color=colors_dict[0],color=colors_dict[0], pattern_shape='\\')))
fig.add_trace(go.Bar(width= 0.2, x=labels, y=strategy_pm25concentration[1,:], name='NonMyopicLatticeSprinkle', marker=dict(line_color=colors_dict[1],color=colors_dict[1], pattern_shape='/')))
fig.add_trace(go.Bar(width= 0.2, x=labels, y=strategy_pm25concentration[2,:], name='MaximumCoverageSprinkle', marker=dict(line_color=colors_dict[2],color=colors_dict[2], pattern_shape='x')))
fig.add_trace(go.Bar(width= 0.2, x=labels, y=strategy_pm25concentration[3,:], name='Non-Sprinkle', marker=dict(line_color=colors_dict[3],color=colors_dict[3], pattern_shape='+')))

fig.update_traces(
    marker=dict(pattern_fillmode="replace", line_width=3, pattern_size=15),
)

fig = bar_update_fig(fig, xtitle, ytitle, width=width, height=height)
fig.update_layout(
    yaxis=dict(range=[0, np.max(strategy_pm25concentration)+10]),
    legend=dict(font=dict(size=30), x=0.5, y=1.22, orientation='h')
    ) # name size
fig.show()
filename = './outputs/png/bar_AveragePollution-teamsize123.png'
print(filename)
# fig.write_image(filename, scale=1)

# %% [markdown]
# # average suppression of pm2.5 concentration for different source number

# %%
# 累计pm2.5控制总量
Setting = pypolo2.utilities.Config()
strategy_name = ["EffectOrientedSelectiveSpray",
                 "NonmyonicLatticeSpray",
                #  "EffectOrientedGreedySpray",
                 "MaximumCoverageSpray",
                 "NoSpray"]
comparing_variables = [["teamsize_1","teamsize_2","teamsize_3"],
                       ["numsource_1","numsource_2","numsource_3","numsource_4"],
                       ["change_interval4","change_interval8","change_interval12"]]
seeds = [7,11,18,20,25,36,42,50,60,72,80,85]
colors_dict = ['#3D9182', '#C74223', '#245C8F', '#FF8C00']
team_sizes = [1,2,3]
sourcenums = [1,2,3,4]
change_intervals = [4,8,12]
strategy_pm25suppression = []
sche_step = 0
adaptive_step = 0
for strategy in strategy_name:
    if strategy == "EffectOrientedGreedySpray":
        sche_step = 18
        adaptive_step = 18
    elif strategy == "NonmyonicLatticeSpray":
        sche_step = 18
        adaptive_step = 4
    else:
        sche_step = 18
        adaptive_step = 3
    variable_pm25suppression = []
    for i in range(3):
        comparing_variable = comparing_variables[1][i]
        team_size = 3
        sourcenum = sourcenums[i]
        seed_pm25suppression = []
        for seed in seeds:
            pklname = f'SEED_{seed}_X{Setting.grid_x}_Y{Setting.grid_y}_VS{team_size}_TS{Setting.max_num_samples}_SS{sche_step}_AS{adaptive_step}_SN{sourcenum}_RS{Setting.replenish_speed}_WV{Setting.water_volume}'
            pkldir = './outputs/' + strategy + '/' + comparing_variable + '/' + pklname + ".pkl"
            data = pypolo2.experiments.utilities.readpkl(pkldir)
            effect = np.sum(data['spray_effect'])/48/400
            seed_pm25suppression.append(effect)
        variable_pm25suppression.append(np.mean(seed_pm25suppression))
    strategy_pm25suppression.append(variable_pm25suppression)
strategy_pm25suppression = np.array(strategy_pm25suppression)

width = 1050
height = 650

labels = np.array(["Numsource 1","Numsource 2","Numsource 3"])
xtitle = 'Pollution Source Number'
ytitle = 'Average suppression of PM2.5(μg/m³)'
fig = go.Figure()
fig.add_trace(go.Bar(
    width= 0.2, 
    x=labels, 
    y=strategy_pm25suppression[0,:], 
    name='SmartSpr', 
    marker=dict(line_color=colors_dict[0],color=colors_dict[0], pattern_shape='\\')))
fig.add_trace(go.Bar(
    width= 0.2, 
    x=labels, 
    y=strategy_pm25suppression[1,:], 
    name='NonMyopicLatticeSprinkle', 
    marker=dict(line_color=colors_dict[1],color=colors_dict[1], pattern_shape='/')))
fig.add_trace(go.Bar(
    width= 0.2, 
    x=labels, 
    y=strategy_pm25suppression[2,:], 
    name='MaximumCoverageSprinkle', 
    marker=dict(line_color=colors_dict[2],color=colors_dict[2], pattern_shape='x')))
fig.add_trace(go.Bar(
    width= 0.2, 
    x=labels, 
    y=strategy_pm25suppression[3,:], 
    name='Non-Sprinkle', 
    marker=dict(line_color=colors_dict[3],color=colors_dict[3], pattern_shape='+')))

fig.update_traces(
    marker=dict(pattern_fillmode="replace", line_width=3, pattern_size=15),
)

fig = bar_update_fig(fig, xtitle, ytitle, width=width, height=height)
fig.update_xaxes(title_text=xtitle, title_font=dict(size=32),tickfont=dict(size=32))
fig.update_yaxes(title_text=ytitle, title_font=dict(size=32),tickfont=dict(size=32))
fig.update_layout(
    yaxis=dict(range=[0, np.max(strategy_pm25suppression)+0.3]),  # 设置y轴范围
    legend=dict(font=dict(size=30), x=0.5, y=1.22, orientation='h')
    )
fig.show()
filename = './outputs/png/bar_AverageSprayEffect-numsource1234.png'
print(filename)
fig.write_image(filename, scale=1)

# %% [markdown]
# # average pm2.5 concentration at last two hours for different source number

# %%
#区域平均污染物浓度
Setting = pypolo2.utilities.Config()
strategy_name = ["EffectOrientedSelectiveSpray",
                 "NonmyonicLatticeSpray",
                #  "EffectOrientedGreedySpray",
                 "MaximumCoverageSpray",
                 "NoSpray"]
comparing_variables = [["teamsize_1","teamsize_2","teamsize_3"],
                       ["numsource_1","numsource_2","numsource_3","numsource_4"],
                       ["change_interval4","change_interval8","change_interval12"]]
seeds = [7,11,18,20,25,36,42,50,60,72,80,85]
team_sizes = [1,2,3]
sourcenums = [1,2,3,4]
change_intervals = [4,8,12]
total_step = 48
sche_step = 0
adaptive_step = 0
strategy_pm25concentration = []
for strategy in strategy_name:
    if strategy == "EffectOrientedGreedySpray":
        sche_step = 18
        adaptive_step = 18
    elif strategy == "NonmyonicLatticeSpray":
        sche_step = 18
        adaptive_step = 4
    else:
        sche_step = 18
        adaptive_step = 3
    variable_pm25suppression = []
    variable_pm25concentration = []
    for i in range(3):
        comparing_variable = comparing_variables[1][i]
        team_size = 3
        sourcenum = sourcenums[i]
        seed_pm25concentration = []
        for seed in seeds:
            pklname = f'SEED_{seed}_X{Setting.grid_x}_Y{Setting.grid_y}_VS{team_size}_TS{Setting.max_num_samples}_SS{sche_step}_AS{adaptive_step}_SN{sourcenum}_RS{Setting.replenish_speed}_WV{Setting.water_volume}'
            pkldir = './outputs/' + strategy + '/' + comparing_variable + '/' + pklname + ".pkl"
            data = pypolo2.experiments.utilities.readpkl(pkldir)
            time_pm25concentration = []
            for j in range(total_step):
                if j > 24:
                    pm25concentration = np.mean(data['truth_env'][j])
                    time_pm25concentration.append(pm25concentration)
            seed_pm25concentration.append(np.mean(time_pm25concentration))
        variable_pm25concentration.append(np.mean(seed_pm25concentration))
    strategy_pm25concentration.append(variable_pm25concentration)
strategy_pm25concentration = np.array(strategy_pm25concentration)

width = 1050
height = 650
colors_dict = ['#3D9182', '#C74223', '#245C8F', '#FF8C00']

labels = np.array(["Numsource 1","Numsource 2","Numsource 3"])
xtitle = 'Pollution Source Number'
ytitle = 'pm2.5 concentration(μg/m³)'
fig = go.Figure()
fig.add_trace(go.Bar(
    width= 0.2, 
    x=labels, 
    y=strategy_pm25concentration[0,:], 
    name='SmartSpr', 
    marker=dict(line_color=colors_dict[0],color=colors_dict[0], pattern_shape='\\')))
fig.add_trace(go.Bar(
    width= 0.2, 
    x=labels, 
    y=strategy_pm25concentration[1,:], 
    name='NonMyopicLatticeSprinkle', 
    marker=dict(line_color=colors_dict[1],color=colors_dict[1], pattern_shape='/')))
fig.add_trace(go.Bar(
    width= 0.2, 
    x=labels, 
    y=strategy_pm25concentration[2,:], 
    name='MaximumCoverageSprinkle', 
    marker=dict(line_color=colors_dict[2],color=colors_dict[2], pattern_shape='x')))
fig.add_trace(go.Bar(
    width= 0.2, 
    x=labels, 
    y=strategy_pm25concentration[3,:], 
    name='Non-Sprinkle', 
    marker=dict(line_color=colors_dict[3],color=colors_dict[3], pattern_shape='+')))
fig.update_traces(
    marker=dict(pattern_fillmode="replace", line_width=3, pattern_size=15),
)

fig = bar_update_fig(fig, xtitle, ytitle, width=width, height=height)
fig.update_xaxes(title_text=xtitle, title_font=dict(size=32),tickfont=dict(size=32))
fig.update_yaxes(title_text=ytitle, title_font=dict(size=32),tickfont=dict(size=32))
fig.update_layout(
    yaxis=dict(range=[0, np.max(strategy_pm25concentration)+5]),
    legend=dict(font=dict(size=30), x=0.5, y=1.22, orientation='h')
    ) # name size
fig.show()
filename = './outputs/png/bar_AveragePollution-numsource1234.png'
print(filename)
fig.write_image(filename, scale=1)

# %% [markdown]
# # cumulative suppression of pm2.5 concentration for different R change intervals

# %%
# 累计pm2.5控制总量
Setting = pypolo2.utilities.Config()
strategy_name = ["PINNsOnlySpray",
                 "SequentialSpray",
                 "NoSpray"]
comparing_variables = [["teamsize_3","teamsize_6","teamsize_9"],
                       ["numsource_2","numsource_4","numsource_6","numsource_8"],
                       ["change_interval4","change_interval8","change_interval12"]]
seeds = [0,3,7,11,15,18,20,32,42,50,55,60,66,70]
team_sizes = [3,6,9]
sourcenums = [2,4,6,8]
change_intervals = [4,8,12]
strategy_pm25suppression = []
for strategy in strategy_name:
    variable_pm25suppression = []
    for i in range(3):
        comparing_variable = comparing_variables[2][i]
        team_size = 5
        sourcenum = 4
        seed_pm25suppression = []
        for seed in seeds:
            pklname = f'SEED_{seed}_X{Setting.grid_x}_Y{Setting.grid_y}_VS{team_size}_TS{Setting.max_num_samples}_SS{Setting.sche_step}_AS{Setting.adaptive_step}_SN{sourcenum}_RS{Setting.replenish_speed}_WV{Setting.water_volume}'
            pkldir = './outputs/' + strategy + '/' + comparing_variable + '/' + pklname + ".pkl"
            data = pypolo2.experiments.utilities.readpkl(pkldir)
            effect = np.sum(data['spray_effect'])
            seed_pm25suppression.append(effect)
        variable_pm25suppression.append(np.mean(seed_pm25suppression))
    strategy_pm25suppression.append(variable_pm25suppression)
strategy_pm25suppression = np.array(strategy_pm25suppression)

width = 1000
height = 650
colors_dict = ['#C74223', '#3D9182', '#245C8F']

labels = np.array(["change_interval4","change_interval8","change_interval12"])
xtitle = 'source change interval'
ytitle = 'cumulative suppression of pm2.5(μg/m³)'
fig = go.Figure()
fig.add_trace(go.Bar(width= 0.23, x=labels, y=strategy_pm25suppression[0,:], name='EffectOrientedSpray', marker=dict(line_color=colors_dict[2],color=colors_dict[2], pattern_shape='\\')))
fig.add_trace(go.Bar(width= 0.23, x=labels, y=strategy_pm25suppression[1,:], name='MaximumCoverageSpray', marker=dict(line_color=colors_dict[0],color=colors_dict[0], pattern_shape='x')))
fig.add_trace(go.Bar(width= 0.23, x=labels, y=strategy_pm25suppression[2,:], name='NoSpray', marker=dict(line_color=colors_dict[1],color=colors_dict[1], pattern_shape='+')))

fig.update_traces(
    marker=dict(pattern_fillmode="replace", line_width=3, pattern_size=15),
)

fig = bar_update_fig(fig, xtitle, ytitle, width=width, height=height)
fig.update_layout(legend=dict(font=dict(size=26), x=0.5, y=1.12, orientation='h')) # name size
fig.show()
# filename = '../outputs/png/bar_原污染源消失产生新污染源.png'
# print(filename)
# fig.write_image(filename, scale=1)

# %% [markdown]
# # average pm2.5 concentration at last two hours for different source change interval

# %%
#区域平均污染物浓度
Setting = pypolo2.utilities.Config()
strategy_name = ["PINNsOnlySpray",
                 "SequentialSpray",
                 "NoSpray"]
comparing_variables = [["teamsize_3","teamsize_6","teamsize_9"],
                       ["numsource_2","numsource_4","numsource_6","numsource_8"],
                       ["change_interval4","change_interval8","change_interval12"]]
seeds = [0,3,7,11,15,18,20,32,42,50,55,60,66,70]
team_sizes = [3,6,9]
sourcenums = [2,4,6,8]
change_intervals = [4,8,12]
total_step = 48

strategy_pm25concentration = []
for strategy in strategy_name:
    variable_pm25concentration = []
    for i in range(3):
        comparing_variable = comparing_variables[2][i]
        team_size = 5
        sourcenum = 4
        seed_pm25concentration = []
        for seed in seeds:
            pklname = f'SEED_{seed}_X{Setting.grid_x}_Y{Setting.grid_y}_VS{team_size}_TS{Setting.max_num_samples}_SS{Setting.sche_step}_AS{Setting.adaptive_step}_SN{sourcenum}_RS{Setting.replenish_speed}_WV{Setting.water_volume}'
            pkldir = './outputs/' + strategy + '/' + comparing_variable + '/' + pklname + ".pkl"
            data = pypolo2.experiments.utilities.readpkl(pkldir)
            time_pm25concentration = []
            for j in range(total_step):
                if j > 36:
                    pm25concentration = np.mean(data['truth_env'][j])
                    time_pm25concentration.append(pm25concentration)
            seed_pm25concentration.append(np.mean(time_pm25concentration))
        variable_pm25concentration.append(np.mean(seed_pm25concentration))
    strategy_pm25concentration.append(variable_pm25concentration)
strategy_pm25concentration = np.array(strategy_pm25concentration)

width = 1000
height = 650
colors_dict = ['#C74223', '#3D9182', '#245C8F']

labels = np.array(["change_interval4","change_interval8","change_interval12"])
xtitle = 'source change interval'
ytitle = 'pm2.5 concentration(μg/m³)'
fig = go.Figure()
fig.add_trace(go.Bar(width= 0.23, x=labels, y=strategy_pm25concentration[0,:], name='EffectOrientedSpray', marker=dict(line_color=colors_dict[2],color=colors_dict[2], pattern_shape='\\')))
fig.add_trace(go.Bar(width= 0.23, x=labels, y=strategy_pm25concentration[1,:], name='MaximumCoverageSpray', marker=dict(line_color=colors_dict[0],color=colors_dict[0], pattern_shape='x')))
fig.add_trace(go.Bar(width= 0.23, x=labels, y=strategy_pm25concentration[2,:], name='NoSpray', marker=dict(line_color=colors_dict[1],color=colors_dict[1], pattern_shape='+')))

fig.update_traces(
    marker=dict(pattern_fillmode="replace", line_width=3, pattern_size=15),
)

fig = bar_update_fig(fig, xtitle, ytitle, width=width, height=height)
fig.update_layout(legend=dict(font=dict(size=26), x=0.5, y=1.12, orientation='h')) # name size
fig.show()
# filename = '../outputs/png/bar_原污染源消失产生新污染源.png'
# print(filename)
# fig.write_image(filename, scale=1)
